# %%
import cv2
import pandas as pd
from PIL import Image

# %%
full_labels = pd.read_csv('data/waldo_labels.csv')

# %%
full_labels.head()
# Out:
#       filename  width  height  class  xmin  ymin  xmax  ymax
# 0  Odlaw01.jpg    200     200  odlaw   123    41   144    82
# 1  Odlaw02.jpg    200     200  odlaw    48   121    70   165
# 2  Odlaw03.jpg    200     200  odlaw    68    62    88    96
# 3  Odlaw04.jpg    200     200  odlaw    82    41   124    98
# 4  Odlaw05.jpg    200     200  odlaw    84    56   107    97

# %%
def draw_boxes(image_name):
    selected_value = full_labels[full_labels.filename == image_name]
    img = cv2.imread('images/{}'.format(image_name))
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('Odlaw01.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119D6BFD0>

# %%
Image.fromarray(draw_boxes('Odlaw02.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E12320>

# %%
Image.fromarray(draw_boxes('Odlaw03.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E123C8>

# %%
Image.fromarray(draw_boxes('Odlaw04.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E12438>

# %%
Image.fromarray(draw_boxes('Odlaw05.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E12518>

# %%
Image.fromarray(draw_boxes('Odlaw06.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E12668>

# %%
Image.fromarray(draw_boxes('wb01.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E129B0>

# %%
Image.fromarray(draw_boxes('Wenda01.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E12AC8>

# %%
Image.fromarray(draw_boxes('Waldo08.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x119E127F0>
